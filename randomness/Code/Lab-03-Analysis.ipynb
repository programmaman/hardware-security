# %% [markdown]
# __Lab 03 - Analysis__
#
# Student Names: Alec Braynen | Jasmin Kuar
#
# Group Number: 7

# %% [markdown]
# # Setup

# %% [markdown]
# Below will import the `TRNGtester` class from the `NIST.py` script to test the random data.
#
# Also, add any other library here that you may need to import.

# %%
from NIST import TRNGtester
import numpy as np
import matplotlib.pyplot as plt

print("✔️ OK to continue!")
# Out:
# ✔️ OK to continue!

# %% [markdown]
# # Test and get P-Values

# %% [markdown]
# Instantiate a `TRNGtester` object to load the random data. Then, call the `run_nist_tests()` method from this object to generate the _list of list_ of p-values. Each sub-list correspond to each test. Some test may have multiple p-values -- only use the _minimum_ from each test.
#
# Repeat this for each dataset (i.e., 1M and 10M bits from both the RO/LFSR TRNG and the GARO TRNG)

# %%
test = TRNGtester("../Data/RO_1M.bin")
print("Running tests on RO 1M Data.")
RO_results_1M = test.run_nist_tests()

test = TRNGtester("../Data/RO_10M.bin")
print("Running tests on RO 10M Data.")
RO_results_10M = test.run_nist_tests()

test = TRNGtester("../Data/GARO_1M.bin")
print("Running tests on GARO 1M Data.")
GARO_results_1M = test.run_nist_tests()

test = TRNGtester("../Data/GARO_10M.bin")
print("Running tests on GARO 10M Data.")
GARO_results_10M = test.run_nist_tests()

print("✔️ OK to continue!")
# Out:
# Running tests on RO 1M Data.
# Starting: monobit_test
# 		Results (p-value(s), Pass/Fail) =
# 			[0.0, False]
# ✔️ Test completed in 0.0006730556488037109s
#
#
# Starting: frequency_within_block_test
# 		Results (p-value(s), Pass/Fail) =
# 			[0.0, False]
# ✔️ Test completed in 0.0003104209899902344s
#
#
# Starting: runs_test
# 		Results (p-value(s), Pass/Fail) =
# 			[0.0, False]
# ✔️ Test completed in 0.0012390613555908203s
#
#
# Starting: longest_run_within_block_test
# 		Results (p-value(s), Pass/Fail) =
# 			[2.732820682669603e-33, False]
# ✔️ Test completed in 0.0011725425720214844s
#
#
# Starting: binary_matrix_rank_test
# 		Results (p-value(s), Pass/Fail) =
# 			[0.11167832245206505, True]
# ✔️ Test completed in 0.011989593505859375s
#
#
# Starting: discrete_fourier_transform_test
# 		Results (p-value(s), Pass/Fail) =
# 			[0.0, False]
# ✔️ Test completed in 0.02608966827392578s
#
#
# Starting: non_overlapping_template_matching_test
# 		Results (p-value(s), Pass/Fail) =
# ...

# %% [markdown]
# # Stats

# %% [markdown]
# Calculate: how many tests passed (p-value ≥ 0.01) or failed (p-value < 0.01)?
#
# Repeat this for each dataset (i.e., 1M and 10M bits from both the RO/LFSR TRNG and the GARO TRNG)

# %%
count_pass = 0
count_fail = 0
RO_1M_list = []
for i in RO_results_1M:
    RO_1M_list.append(np.min(i))
    print(min(i))
    if min(i) < 0.01:
        count_fail += 1
    elif min(i) >= 0.01:
        count_pass += 1  
print("RO 1MIL Results:")
print("Tests failed:", count_fail)
print("Tests passed:", count_pass)

count_pass = 0
count_fail = 0

RO_10M_list = []
for i in RO_results_10M:
    RO_10M_list.append(np.min(i))
    print(min(i))
    if min(i) < 0.01:
        count_fail += 1
    elif min(i) >= 0.01:
        count_pass += 1   
print("RO 10MIL Results:")
print("Tests failed:", count_fail)
print("Tests passed:", count_pass)

count_pass = 0
count_fail = 0

GARO_1M_list = []
for i in GARO_results_1M:
    print(min(i))
    GARO_1M_list.append(np.min(i))
    if min(i) < 0.01:
        count_fail += 1
    elif min(i) >= 0.01:
        count_pass += 1  
print("GARO 1MIL Results:")
print("Tests failed:", count_fail)
print("Tests passed:", count_pass)
 
count_pass = 0
count_fail = 0 

GARO_10M_list = []
for i in GARO_results_1M:
    print(min(i))
    GARO_10M_list.append(np.min(i))
    if min(i) < 0.01:
        count_fail += 1
    elif min(i) >= 0.01:
        count_pass += 1 
        
print("GARO 10MIL Results:")
print("Tests failed:", count_fail)
print("Tests passed:", count_pass)
    
print("Done.")
# Out:
# 0.0
# 0.0
# 0.0
# 2.732820682669603e-33
# 0.11167832245206505
# 0.0
# 5.070043554787841e-308
# 1.6913300424630313e-78
# 1.799857622779191e-296
# 0.9929649073527211
# 1.0
# 0.0
# 8.69412735759734e-236
# 9.044127057869422e-06
# 0.3786379026593538
# RO 1MIL Results:
# Tests failed: 11
# Tests passed: 4
# 0.0
# 0.0
# 0.0
# 0.0
# 0.5314473597676562
# 0.0
# 0.0
# 0.0
# 0.0
# 0.31515750726300573
# 1.0
# 0.0
# 1.8489884339594058e-25
# 1.2870434012747581e-05
# 0.19452846255092027
# RO 10MIL Results:
# Tests failed: 11
# Tests passed: 4
# 0.9808526087079389
# 0.27236538386653886
# 0.8321074835961424
# 0.6798103460039483
# 0.11607860627005552
# 0.9487819898568091
# 0.003589735184632305
# 0.9122380582063954
# 0.8517829018065136
# 0.4440490558196134
# 0.6168772446361974
# 0.36920277343648095
# 0.5305764913568984
# 0.011599167306461178
# 0.005010443411263504
# GARO 1MIL Results:
# Tests failed: 2
# Tests passed: 13
# 0.9808526087079389
# 0.27236538386653886
# 0.8321074835961424
# ...

# %% [markdown]
# # Plots

# %% [markdown]
# Plot and save (as PDF) a vertical bar graph for the NIST test. Make sure to format the plots with adequate size, title, axis labels, ... (see the Tutorial-01-Python).
#
# To generate vertical bar graphs, use `plt.bar()`. Read more: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
#
# Make sure to annotate each bar indicating if the test `pass` or `fail`, use `plt..annotate()`. Read more: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html

# %%
results = RO_1M_list

x_axis = []
pass_fail = []


for i in range(len(results)):
    x_axis.append("T" + str(i))
    if results[i] < 0.01:
        pass_fail.append("X")
    elif results [i] > 0.01:
        pass_fail.append("✔️")




# for i in range(len(results)):
#     x_axis.append("Test" + str(i))


# figure properties
plt.figure(figsize=(10,5), constrained_layout=True)


# plots the data
plt.bar(x_axis, results)
plt.annotate(pass_fail[0], (0,0.5))
plt.annotate(pass_fail[1], (1,0.5))
plt.annotate(pass_fail[2], (2,0.5))
plt.annotate(pass_fail[3], (3,0.5))
plt.annotate(pass_fail[4], (4,0.5))
plt.annotate(pass_fail[5], (5,0.5))
plt.annotate(pass_fail[6], (6,0.5))
plt.annotate(pass_fail[7], (7,0.5))
plt.annotate(pass_fail[8], (8,0.5))
plt.annotate(pass_fail[9], (9,0.5))
plt.annotate(pass_fail[10], (10,0.5))
plt.annotate(pass_fail[11], (11,0.5))
plt.annotate(pass_fail[12], (12,0.5))
plt.annotate(pass_fail[13], (13,0.5))
plt.annotate(pass_fail[14], (14,0.5))


# # format your plots
plt.title("RO 1 Million Bits Test p-values Results")            # adds title
plt.xlabel("NIST Test")          # adds x-axis label
plt.ylabel("p-score")          # adds y-axis label
# plt.xlim(0, 3)               # sets x-axis min/max values
# plt.ylim(0, 1.01)             # sets y-axis min/max values


# saves the plot
plt.savefig("../Figures/RO_1M.pdf") # PDF recommended



# show the plot on your screen
plt.show()

# %%
results = RO_10M_list

x_axis = []
pass_fail = []


for i in range(len(results)):
    x_axis.append("T" + str(i))
    if results[i] < 0.01:
        pass_fail.append("X")
    elif results [i] > 0.01:
        pass_fail.append("✔️")




# for i in range(len(results)):
#     x_axis.append("Test" + str(i))


# figure properties
plt.figure(figsize=(10,5), constrained_layout=True)


# plots the data
plt.bar(x_axis, results)
plt.annotate(pass_fail[0], (0,0.5))
plt.annotate(pass_fail[1], (1,0.5))
plt.annotate(pass_fail[2], (2,0.5))
plt.annotate(pass_fail[3], (3,0.5))
plt.annotate(pass_fail[4], (4,0.5))
plt.annotate(pass_fail[5], (5,0.5))
plt.annotate(pass_fail[6], (6,0.5))
plt.annotate(pass_fail[7], (7,0.5))
plt.annotate(pass_fail[8], (8,0.5))
plt.annotate(pass_fail[9], (9,0.5))
plt.annotate(pass_fail[10], (10,0.5))
plt.annotate(pass_fail[11], (11,0.5))
plt.annotate(pass_fail[12], (12,0.5))
plt.annotate(pass_fail[13], (13,0.5))
plt.annotate(pass_fail[14], (14,0.5))


# # format your plots
plt.title("RO 10 Million Bits Test p-values Results")            # adds title
plt.xlabel("NIST Test")          # adds x-axis label
plt.ylabel("p-score")          # adds y-axis label
# plt.xlim(0, 3)               # sets x-axis min/max values
# plt.ylim(0, 1.01)             # sets y-axis min/max values


# saves the plot
plt.savefig("../Figures/RO_10M.pdf") # PDF recommended



# show the plot on your screen
plt.show()

# %%
results = GARO_1M_list

x_axis = []
pass_fail = []


for i in range(len(results)):
    x_axis.append("T" + str(i))
    if results[i] < 0.01:
        pass_fail.append("X")
    elif results [i] > 0.01:
        pass_fail.append("✔️")




# for i in range(len(results)):
#     x_axis.append("Test" + str(i))


# figure properties
plt.figure(figsize=(10,5), constrained_layout=True)


# plots the data
plt.bar(x_axis, results)
plt.annotate(pass_fail[0], (0,0.5))
plt.annotate(pass_fail[1], (1,0.5))
plt.annotate(pass_fail[2], (2,0.5))
plt.annotate(pass_fail[3], (3,0.5))
plt.annotate(pass_fail[4], (4,0.5))
plt.annotate(pass_fail[5], (5,0.5))
plt.annotate(pass_fail[6], (6,0.5))
plt.annotate(pass_fail[7], (7,0.5))
plt.annotate(pass_fail[8], (8,0.5))
plt.annotate(pass_fail[9], (9,0.5))
plt.annotate(pass_fail[10], (10,0.5))
plt.annotate(pass_fail[11], (11,0.5))
plt.annotate(pass_fail[12], (12,0.5))
plt.annotate(pass_fail[13], (13,0.5))
plt.annotate(pass_fail[14], (14,0.5))


# # format your plots
plt.title("GARO 1 Million Bits Test p-values Results")            # adds title
plt.xlabel("NIST Test")          # adds x-axis label
plt.ylabel("p-score")          # adds y-axis label
# plt.xlim(0, 3)               # sets x-axis min/max values
# plt.ylim(0, 1.01)             # sets y-axis min/max values


# saves the plot
plt.savefig("../Figures/GARO_1M.pdf") # PDF recommended



# show the plot on your screen
plt.show()

# %%
results = GARO_10M_list

x_axis = []
pass_fail = []


for i in range(len(results)):
    x_axis.append("T" + str(i))
    if results[i] < 0.01:
        pass_fail.append("X")
    elif results [i] > 0.01:
        pass_fail.append("✔️")




# for i in range(len(results)):
#     x_axis.append("Test" + str(i))


# figure properties
plt.figure(figsize=(10,5), constrained_layout=True)


# plots the data
plt.bar(x_axis, results)
plt.annotate(pass_fail[0], (0,0.5))
plt.annotate(pass_fail[1], (1,0.5))
plt.annotate(pass_fail[2], (2,0.5))
plt.annotate(pass_fail[3], (3,0.5))
plt.annotate(pass_fail[4], (4,0.5))
plt.annotate(pass_fail[5], (5,0.5))
plt.annotate(pass_fail[6], (6,0.5))
plt.annotate(pass_fail[7], (7,0.5))
plt.annotate(pass_fail[8], (8,0.5))
plt.annotate(pass_fail[9], (9,0.5))
plt.annotate(pass_fail[10], (10,0.5))
plt.annotate(pass_fail[11], (11,0.5))
plt.annotate(pass_fail[12], (12,0.5))
plt.annotate(pass_fail[13], (13,0.5))
plt.annotate(pass_fail[14], (14,0.5))


# # format your plots
plt.title("GARO 10 Million Bits Test p-values Results")            # adds title
plt.xlabel("NIST Test")          # adds x-axis label
plt.ylabel("p-score")          # adds y-axis label
# plt.xlim(0, 3)               # sets x-axis min/max values
# plt.ylim(0, 1.01)             # sets y-axis min/max values



# saves the plot
plt.savefig("../Figures/GARO_10M.pdf") # PDF recommended



# show the plot on your screen
plt.show()
